# %% [markdown]
# # Creating Star Schema

# %% [markdown]
# This notebook explores the creation of a Star Schema from raw data using Apache Spark.
#
# The data used in this notebook is from the Brazilian Basic Education Census, which is available at the [Brazilian government's open data portal](https://download.inep.gov.br/dados_abertos)

# %% [markdown]
# ## Creating SparkSession

# %% [markdown]
# The first step is to create a SparkSession.

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

import psycopg2
from datetime import datetime

from itertools import chain

# %%
spark = SparkSession.builder\
        .appName("CensoEscolarStarSchema")\
        .config("spark.sql.shuffle.partitions", "4")\
        .config("spark.driver.memory", "8g")\
        .config("spark.executor.memory", "8g")\
        .getOrCreate()

# %%
#additional checking
import os
print(os.getcwd())
# Out:
# C:\posts-main\etl_spark_scholar_census

# %% [markdown]
# ## Transforming CSV to Parquet

# %% [markdown]
# This transformation aims to increase the speed of data loading by using Parquet files.

# %%
#additional checking
import os
files = os.listdir("./data")
print(files)
# Out:
# ['2010.csv', '2011.csv', '2012.csv', '2013.csv', '2014.csv', '2015.csv', '2016.csv', '2017.csv', '2018.csv', '2019.csv', '2020.csv', '2021.csv', 'censo_escolar.parquet']

# %%
# Read CSV data
#data_csv = (
#    spark
#    .read
 #   .format("csv")
#    .option("header", "true")
#    .option("inferSchema", "false")
#    .option("delimiter", ";")
#    .option("encoding", "latin1")
#    .load("C:/posts-main/etl_spark_scholar_census/data/*.csv")
#)
import glob

csv_files = glob.glob("C:/posts-main/etl_spark_scholar_census/data/*.csv")

data_csv = (
    spark
    .read
    .format("csv")
    .option("header", "true")
    .option("inferSchema", "false")
    .option("delimiter", ";")
    .option("encoding", "iso-8859-1")
    .load(csv_files)
)

# %% [markdown]
# Write to Parquet file

# %%
data_csv.write.parquet("./data/censo_escolar.parquet")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data_csv.write.parquet("./data/censo_escolar.parquet")
#
# File ~\anaconda3\Lib\site-packages\pyspark\sql\readwriter.py:2003, in DataFrameWriter.parquet(self, path, mode, partitionBy, compression)
#    2001     self.partitionBy(partitionBy)
#    2002 self._set_opts(compression=compression)
# -> 2003 self._jwrite.parquet(path)
#
# File ~\anaconda3\Lib\site-packages\py4j\java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File ~\anaconda3\Lib\site-packages\pyspark\errors\exceptions\captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# AnalysisException: [PATH_ALREADY_EXISTS] Path file:/C:/posts-main/etl_spark_scholar_census/data/censo_escolar.parquet already exists. Set mode as "overwrite" to overwrite the existing path. SQLSTATE: 42K04

# %%
#additional checking
import os
os.listdir("C:/posts-main/etl_spark_scholar_census/data/censo_escolar.parquet")
# Out:
# ['.part-00000-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00001-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00002-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00003-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00004-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00005-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00006-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00007-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00008-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00009-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00010-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00011-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00012-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00013-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00014-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00015-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00016-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00017-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00018-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00019-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00020-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00021-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00022-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '.part-00023-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet.crc',
#  '._SUCCESS.crc',
#  'part-00000-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00001-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00002-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00003-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00004-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00005-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00006-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00007-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00008-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00009-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00010-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00011-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00012-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00013-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00014-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00015-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00016-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00017-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00018-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00019-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00020-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00021-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00022-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  'part-00023-a2d7b66a-42d3-41c7-a652-fc01082550f6-c000.snappy.parquet',
#  '_SUCCESS']

# %% [markdown]
# Reading from Parquet file

# %%
data = (
    spark
    .read
    .format("parquet")
    .load("./data/censo_escolar.parquet/")
)

# %%
#additional checking
print(data.count())
print(len(data.columns))
# Out:
# 2792984
# 370

# %% [markdown]
# ## Dimensions

# %% [markdown]
# The dimensions are...
#
# ---

# %% [markdown]
# The code below creates the dimensions based on a configuration dict.
#
# ```json
# {
#     "DIM_NAME":{
#         # The fields are the table columns
#         "fields":[
#             {
#                 "field":"FIELD_1_NAME", # The column name
#                 "type":"FIELD_1_TYPE",  # The column type in spark
#             },
#             {
#                 "field":"FIELD_2_NAME",
#                 "type":"FIELD_2_TYPE",
#             },
#             ...
#         ],
#     }
# }
# ```

# %%
INTEGER_DIMENSIONS = [
    "TP_DEPENDENCIA",
    "TP_LOCALIZACAO",
    "IN_AGUA_POTAVEL",
    "IN_ENERGIA_INEXISTENTE",
    "IN_ESGOTO_INEXISTENTE",
    "IN_BANHEIRO",
    "IN_BIBLIOTECA",
    "IN_REFEITORIO",
    "IN_COMPUTADOR",
    "IN_INTERNET",
    "IN_EQUIP_NENHUM"
]

DIMENSION_TABLES_CONFIG = {
    "DIM_LOCAL":{
        "fields": [
            {"field":"NO_UF", "type":"string",},
            {"field":"SG_UF", "type":"string",},
            {"field":"CO_UF", "type":"string",},
            {"field":"NO_MUNICIPIO", "type":"string",},
            {"field":"CO_MUNICIPIO", "type":"string",}
        ]
    },
}

DIMENSION_TABLES_CONFIG.update(
    {
        "DIM_"+dimension.upper():{
            "fields": [
                {"field":dimension, "type":"integer"} 
            ]
        }
        for dimension in INTEGER_DIMENSIONS
    }
)
print("✅ Dimension config ready!")
print(f"Total dimensions: {len(DIMENSION_TABLES_CONFIG)}")
# Out:
# ✅ Dimension config ready!
# Total dimensions: 12

# %% [markdown]
# ### Creating dimensions table in Postgres
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Defining the properties of the Postgres Connection

# %%
POSTGRES_USER = "censo"
POSTGRES_PASSWORD = "123"
POSTGRES_DB = "censo_escolar"

# Used to connect to the PostgreSQL database server
# in spark session
POSTGRES_CONFIG = {
    "url":f"jdbc:postgresql://localhost:5432/{POSTGRES_DB}",
    "properties":{
        "user":POSTGRES_USER, 
        "password":POSTGRES_PASSWORD,
        "driver":"org.postgresql.Driver",
        
    },
}

# %% [markdown]
# Establishing connection to Postgres

# %%
conn = psycopg2.connect(
    host="localhost",
    port="5432",

    dbname=POSTGRES_DB,
    user=POSTGRES_USER,
    password=POSTGRES_PASSWORD
)

# %% [markdown]
# Function to create a Dimension table in Postgres using the configuration in DIMENSION_TABLES_CONFIG and adding an id column

# %% [markdown]
# The code below creates the dimensions
# Spark will create a table with the name of the dimension and the columns in the configuration

# %%
# Write data to Postgres
# Using the configuration in DIMENSION_TABLES_CONFIG
# With id as the primary key

for table_name, table_config in DIMENSION_TABLES_CONFIG.items():
    
    print(f"[{datetime.now()}] Writing {table_name}")
    
    data\
    .select(
        [
            F
            .col(field["field"])
            .cast(field["type"])
            .alias(field["field"])
            
            for field
            in table_config["fields"]
        ]
    )\
    .distinct()\
    .withColumn(
        "id", F.monotonically_increasing_id()
    )\
    .write\
    .jdbc(
        **POSTGRES_CONFIG,
        table=table_name,
        mode="overwrite"
    )
    
    print(f"[{datetime.now()}] Wrote {table_name}")
    # Define id as the primary key
    cursor = conn.cursor()
    cursor.execute(
        f"ALTER TABLE {table_name} ADD PRIMARY KEY (id);"
    )
    cursor.close()
    conn.commit()

    print(f"[{datetime.now()}] Added primary key to {table_name}")
    print(f"[{datetime.now()}] Done")
# Out:
# [2026-05-14 18:22:22.401288] Writing DIM_LOCAL
# [2026-05-14 18:22:26.905043] Wrote DIM_LOCAL
# [2026-05-14 18:22:26.943968] Added primary key to DIM_LOCAL
# [2026-05-14 18:22:26.944084] Done
# [2026-05-14 18:22:26.944102] Writing DIM_TP_DEPENDENCIA
# [2026-05-14 18:22:28.406476] Wrote DIM_TP_DEPENDENCIA
# [2026-05-14 18:22:28.440522] Added primary key to DIM_TP_DEPENDENCIA
# [2026-05-14 18:22:28.440678] Done
# [2026-05-14 18:22:28.440708] Writing DIM_TP_LOCALIZACAO
# [2026-05-14 18:22:29.173676] Wrote DIM_TP_LOCALIZACAO
# [2026-05-14 18:22:29.187705] Added primary key to DIM_TP_LOCALIZACAO
# [2026-05-14 18:22:29.187847] Done
# [2026-05-14 18:22:29.187874] Writing DIM_IN_AGUA_POTAVEL
# [2026-05-14 18:22:29.794582] Wrote DIM_IN_AGUA_POTAVEL
# [2026-05-14 18:22:29.805841] Added primary key to DIM_IN_AGUA_POTAVEL
# [2026-05-14 18:22:29.805942] Done
# [2026-05-14 18:22:29.805959] Writing DIM_IN_ENERGIA_INEXISTENTE
# [2026-05-14 18:22:30.376507] Wrote DIM_IN_ENERGIA_INEXISTENTE
# [2026-05-14 18:22:30.386320] Added primary key to DIM_IN_ENERGIA_INEXISTENTE
# [2026-05-14 18:22:30.386388] Done
# [2026-05-14 18:22:30.386401] Writing DIM_IN_ESGOTO_INEXISTENTE
# [2026-05-14 18:22:30.911211] Wrote DIM_IN_ESGOTO_INEXISTENTE
# [2026-05-14 18:22:30.923327] Added primary key to DIM_IN_ESGOTO_INEXISTENTE
# [2026-05-14 18:22:30.923431] Done
# [2026-05-14 18:22:30.923446] Writing DIM_IN_BANHEIRO
# [2026-05-14 18:22:31.589746] Wrote DIM_IN_BANHEIRO
# [2026-05-14 18:22:31.601553] Added primary key to DIM_IN_BANHEIRO
# [2026-05-14 18:22:31.601681] Done
# [2026-05-14 18:22:31.601704] Writing DIM_IN_BIBLIOTECA
# [2026-05-14 18:22:32.295902] Wrote DIM_IN_BIBLIOTECA
# [2026-05-14 18:22:32.312846] Added primary key to DIM_IN_BIBLIOTECA
# [2026-05-14 18:22:32.312966] Done
# [2026-05-14 18:22:32.312989] Writing DIM_IN_REFEITORIO
# [2026-05-14 18:22:32.823951] Wrote DIM_IN_REFEITORIO
# [2026-05-14 18:22:32.835499] Added primary key to DIM_IN_REFEITORIO
# [2026-05-14 18:22:32.835637] Done
# [2026-05-14 18:22:32.835659] Writing DIM_IN_COMPUTADOR
# [2026-05-14 18:22:33.481875] Wrote DIM_IN_COMPUTADOR
# [2026-05-14 18:22:33.515318] Added primary key to DIM_IN_COMPUTADOR
# [2026-05-14 18:22:33.515510] Done
# [2026-05-14 18:22:33.515541] Writing DIM_IN_INTERNET
# [2026-05-14 18:22:34.319705] Wrote DIM_IN_INTERNET
# [2026-05-14 18:22:34.334344] Added primary key to DIM_IN_INTERNET
# [2026-05-14 18:22:34.334480] Done
# [2026-05-14 18:22:34.334498] Writing DIM_IN_EQUIP_NENHUM
# [2026-05-14 18:22:35.202788] Wrote DIM_IN_EQUIP_NENHUM
# [2026-05-14 18:22:35.242909] Added primary key to DIM_IN_EQUIP_NENHUM
# [2026-05-14 18:22:35.243346] Done

# %% [markdown]
# ## Facts table

# %% [markdown]
# The definition of the facts table follows a different pattern than the dimensions.
#
# The table schema is previously defined to properly define the foreing keys.

# %% [markdown]
# Defining the facts table schema
# Metrics + Facts + Dimensions (Foreign Keys)

# %%
FACT_TABLE_NAME = "FACT_CENSO_ESCOLAR"

FACT_COLUMNS = [
    "QT_DOC_BAS",	# Número de Docentes da Educação Básica
    "QT_DOC_INF",	# Número de Docentes da Educação Infantil
    "QT_DOC_FUND",	# Número de Docentes do Ensino Fundamental
    "QT_DOC_MED",	# Número de Docentes do Ensino Médio

    "QT_MAT_BAS",	# Número de Matrículas na Educação Básica (TOTAL)
    "QT_MAT_INF",	# Número de Matrículas na Educação Infantil
    "QT_MAT_FUND",	# Número de Matrículas no Ensino Fundamental
    "QT_MAT_MED",	# Número de Matrículas no Ensino Médio

    "QT_MAT_BAS_ND",	    # Número de Matrículas na Educação Básica - Cor/Raça Não Declarada
    "QT_MAT_BAS_BRANCA",	# Número de Matrículas na Educação Básica - Cor/Raça Branca
    "QT_MAT_BAS_PRETA",	    # Número de Matrículas na Educação Básica - Cor/Raça Preta
    "QT_MAT_BAS_PARDA",	    # Número de Matrículas na Educação Básica - Cor/Raça Parda
    "QT_MAT_BAS_AMARELA",	# Número de Matrículas na Educação Básica - Cor/Raça Amarela
    "QT_MAT_BAS_INDIGENA",	# Número de Matrículas na Educação Básica - Cor/Raça Indígena
    
    "NU_ANO_CENSO"
]

FACT_CONFIG = {
    fact:{
        "fields": [
            {"field":fact, "type":"integer"}
        ]
    }
    for fact in FACT_COLUMNS
}

DIMENSION_ID_CONFIG = {
    table_name:[
        field['field'] 
        for field 
        in table_fields['fields']
    ]
    for table_name, table_fields in DIMENSION_TABLES_CONFIG.items()
}

FACT_TABLE_ALL_COLUMNS_ORDERED = FACT_COLUMNS + list(map(lambda col:"ID_"+col, DIMENSION_ID_CONFIG.keys()))

print("✅ Fact config ready!")
print(f"Fact columns: {len(FACT_COLUMNS)}")
print(f"Dimension IDs: {len(DIMENSION_ID_CONFIG)}")
print(f"Total ordered columns: {len(FACT_TABLE_ALL_COLUMNS_ORDERED)}")
# Out:
# ✅ Fact config ready!
# Fact columns: 15
# Dimension IDs: 12
# Total ordered columns: 27

# %% [markdown]
# Before inserting the data into the facts table, we need to create a function to create the facts table in Postgres
#
# The code below creates the facts table in Postgres using the configuration in FACT_TABLES_CONFIG and adding an id column for each dimension

# %%
# Create fact table
# Using the configuration in FACT_CONFIG
# With id as the primary key

# Avoid inserting a backslash into a f-string
comma_break_line = ",\n\t\t\t"
facts_table_sql = f"""
    CREATE TABLE IF NOT EXISTS {FACT_TABLE_NAME} (
        id SERIAL PRIMARY KEY,
        { 
            comma_break_line.join(
                [
                    f"{field} INTEGER" 
                    for field in FACT_COLUMNS
                ]
                +[
                    f"ID_{dim_table} BIGINT"
                    for dim_table in DIMENSION_ID_CONFIG.keys()
                ]
            )
        }
    );
    
    -- Adding Foreign Keys
    ALTER TABLE {FACT_TABLE_NAME}
    {
        comma_break_line.join(
            [
                f"ADD CONSTRAINT {FACT_TABLE_NAME}_{dim_table}_fk FOREIGN KEY (ID_{dim_table}) REFERENCES {dim_table}(id)"
                for dim_table in DIMENSION_ID_CONFIG.keys()
            ]
        )
    }
"""

# %%
print(facts_table_sql)
# Out:
#     CREATE TABLE IF NOT EXISTS FACT_CENSO_ESCOLAR (
#         id SERIAL PRIMARY KEY,
#         QT_DOC_BAS INTEGER,
# 			QT_DOC_INF INTEGER,
# 			QT_DOC_FUND INTEGER,
# 			QT_DOC_MED INTEGER,
# 			QT_MAT_BAS INTEGER,
# 			QT_MAT_INF INTEGER,
# 			QT_MAT_FUND INTEGER,
# 			QT_MAT_MED INTEGER,
# 			QT_MAT_BAS_ND INTEGER,
# 			QT_MAT_BAS_BRANCA INTEGER,
# 			QT_MAT_BAS_PRETA INTEGER,
# 			QT_MAT_BAS_PARDA INTEGER,
# 			QT_MAT_BAS_AMARELA INTEGER,
# 			QT_MAT_BAS_INDIGENA INTEGER,
# 			NU_ANO_CENSO INTEGER,
# 			ID_DIM_LOCAL BIGINT,
# 			ID_DIM_TP_DEPENDENCIA BIGINT,
# 			ID_DIM_TP_LOCALIZACAO BIGINT,
# 			ID_DIM_IN_AGUA_POTAVEL BIGINT,
# 			ID_DIM_IN_ENERGIA_INEXISTENTE BIGINT,
# 			ID_DIM_IN_ESGOTO_INEXISTENTE BIGINT,
# 			ID_DIM_IN_BANHEIRO BIGINT,
# 			ID_DIM_IN_BIBLIOTECA BIGINT,
# 			ID_DIM_IN_REFEITORIO BIGINT,
# 			ID_DIM_IN_COMPUTADOR BIGINT,
# 			ID_DIM_IN_INTERNET BIGINT,
# 			ID_DIM_IN_EQUIP_NENHUM BIGINT
#     );
#
#     -- Adding Foreign Keys
#     ALTER TABLE FACT_CENSO_ESCOLAR
#     ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_LOCAL_fk FOREIGN KEY (ID_DIM_LOCAL) REFERENCES DIM_LOCAL(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_TP_DEPENDENCIA_fk FOREIGN KEY (ID_DIM_TP_DEPENDENCIA) REFERENCES DIM_TP_DEPENDENCIA(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_TP_LOCALIZACAO_fk FOREIGN KEY (ID_DIM_TP_LOCALIZACAO) REFERENCES DIM_TP_LOCALIZACAO(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_IN_AGUA_POTAVEL_fk FOREIGN KEY (ID_DIM_IN_AGUA_POTAVEL) REFERENCES DIM_IN_AGUA_POTAVEL(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_IN_ENERGIA_INEXISTENTE_fk FOREIGN KEY (ID_DIM_IN_ENERGIA_INEXISTENTE) REFERENCES DIM_IN_ENERGIA_INEXISTENTE(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_IN_ESGOTO_INEXISTENTE_fk FOREIGN KEY (ID_DIM_IN_ESGOTO_INEXISTENTE) REFERENCES DIM_IN_ESGOTO_INEXISTENTE(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_IN_BANHEIRO_fk FOREIGN KEY (ID_DIM_IN_BANHEIRO) REFERENCES DIM_IN_BANHEIRO(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_IN_BIBLIOTECA_fk FOREIGN KEY (ID_DIM_IN_BIBLIOTECA) REFERENCES DIM_IN_BIBLIOTECA(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_IN_REFEITORIO_fk FOREIGN KEY (ID_DIM_IN_REFEITORIO) REFERENCES DIM_IN_REFEITORIO(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_IN_COMPUTADOR_fk FOREIGN KEY (ID_DIM_IN_COMPUTADOR) REFERENCES DIM_IN_COMPUTADOR(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_IN_INTERNET_fk FOREIGN KEY (ID_DIM_IN_INTERNET) REFERENCES DIM_IN_INTERNET(id),
# 			ADD CONSTRAINT FACT_CENSO_ESCOLAR_DIM_IN_EQUIP_NENHUM_fk FOREIGN KEY (ID_DIM_IN_EQUIP_NENHUM) REFERENCES DIM_IN_EQUIP_NENHUM(id)

# %% [markdown]
# Executing the function to create the facts table in Postgres

# %%
print(f"[{datetime.now()}] Creating facts table")

cursor = conn.cursor()
try:
    cursor.execute(facts_table_sql)
    cursor.close()
    conn.commit()
except Exception as e:
    print(e)
    conn.rollback()
    cursor.close()
else:
    print(f"[{datetime.now()}] Created facts table")
    print(f"[{datetime.now()}] Done")
# Out:
# [2026-05-14 18:26:19.031805] Creating facts table
# [2026-05-14 18:26:19.144199] Created facts table
# [2026-05-14 18:26:19.144360] Done

# %% [markdown]
# Extracting the data

# %%
facts_data = data\
    .select(
        [
            *chain(
                *DIMENSION_ID_CONFIG.values(), 
                FACT_CONFIG.keys()
            )
        ]
    )
print("✅ Facts data extracted!")
print(f"Columns selected: {len(facts_data.columns)}")
# Out:
# ✅ Facts data extracted!
# Columns selected: 31

# %% [markdown]
# Adding the ids for each dimension

# %%
# Joining the id of the dimensions

for table_name, table_fields in DIMENSION_ID_CONFIG.items():
    
    # Read the dimension data from Postgres
    dim_table = spark.read\
        .jdbc(
            **POSTGRES_CONFIG,
            table=table_name,
        )\
        .withColumnRenamed("id", f"ID_{table_name}")
    
    # Join the dimension data with the fact data
    facts_data = facts_data\
        .join(
            dim_table,
            on=table_fields,
            how="left"
        )\
        .drop(*table_fields)

    print(f"Final columns: {len(facts_data.columns)}")
# Out:
# Final columns: 27
# Final columns: 27
# Final columns: 27
# Final columns: 27
# Final columns: 27
# Final columns: 27
# Final columns: 27
# Final columns: 27
# Final columns: 27
# Final columns: 27
# Final columns: 27
# Final columns: 27

# %% [markdown]
# Saving data to Postgres

# %%
# Order the columns to match the fact table on postgres
# and save the data
#facts_data\
 #   .select(*FACT_TABLE_ALL_COLUMNS_ORDERED)\
  #  .write\
   # .jdbc(
    #    **POSTGRES_CONFIG,
     #   table=FACT_TABLE_NAME,
      #  mode="append"
    #)

facts_data\
    .select(
        [F.col(c).cast("integer") if c in FACT_COLUMNS else F.col(c) 
         for c in FACT_TABLE_ALL_COLUMNS_ORDERED]
    )\
    .write\
    .jdbc(
        **POSTGRES_CONFIG,
        table=FACT_TABLE_NAME,
        mode="append"
    )

# %% [markdown]
# ## References

# %% [markdown]
# https://towardsdatascience.com/explaining-technical-stuff-in-a-non-techincal-way-apache-spark-274d6c9f70e9
#
# https://towardsdatascience.com/adding-sequential-ids-to-a-spark-dataframe-fa0df5566ff6
#
# https://sparkbyexamples.com/pyspark/pyspark-read-and-write-parquet-file/
#
# https://www.psycopg.org/docs/usage.html
